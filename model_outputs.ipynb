# %%
require(lme4)
require(lmerTest)
require(emmeans)

load('bimonthly_random3.RData')
# Out:
# Loading required package: lme4
# Loading required package: Matrix

# %%
# MOSQUITO NET COVERAGE ACROSS VILLAGE
by(dat2$mosquito.net, dat2$village, table)
# Out:
# dat2$village: Bana market
#
#  No Yes
#  40 508
# ------------------------------------------------------------
# dat2$village: Bana village
#
#  No Yes
#  61 998
# ------------------------------------------------------------
# dat2$village: Pala
#
#  No Yes
# 178 594
# ------------------------------------------------------------
# dat2$village: Souroukoudingan
#
#  No Yes
#  42 712

# %%
# NUMBER OF HABITANTS ACROSS VILLAGE
by(dat2$num.persons, dat2$village, mean, na.rm=T)
# Out:
# dat2$village: Bana market
# [1] 2.912409
# ------------------------------------------------------------
# dat2$village: Bana village
# [1] 2.575071
# ------------------------------------------------------------
# dat2$village: Pala
# [1] 3.75
# ------------------------------------------------------------
# dat2$village: Souroukoudingan
# [1] 3.55305

# %% [markdown]
# #### 1. Mosquito density

# %%
# MODEL SUMMARY
summary(m_4D)
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: poisson  ( log )
# Formula:
# count.f ~ (1 | year.assigned) + (1 | site.id) + (1 | overdispersion) +
#     (1 | village) + (1 | village:bimonth.assigned) + bimonth.assigned +
#     mosquito.net + persons.status
#    Data: dat2
# Control: glmerControl(optimizer = "bobyqa", optCtrl = list(maxfun = 3e+05))
#
#      AIC      BIC   logLik deviance df.resid
#  16612.2  16696.9  -8292.1  16584.2     3119
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.3124 -0.4960 -0.1069  0.1346  1.8051
#
# Random effects:
#  Groups                   Name        Variance Std.Dev.
#  overdispersion           (Intercept) 1.4413   1.2006
#  site.id                  (Intercept) 0.3127   0.5592
#  village:bimonth.assigned (Intercept) 0.1768   0.4205
#  year.assigned            (Intercept) 0.1881   0.4337
#  village                  (Intercept) 0.1025   0.3202
# ...

# %%
# RESIDUAL PLOT
plot(m_4D)
# Out:
# plot without title

# %% [markdown]
# #### 2. Species composition

# %%
# MODEL SUMMARY
summary(m_5)
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: cbind(col.f, gam.f) ~ (1 | year.assigned) + (1 | site.id) + (1 |
#     overdispersion) + (1 | village) + (1 | village:bimonth.assigned) +
#     bimonth.assigned + mosquito.net + persons.status
#    Data: dat3
# Control: glmerControl(optimizer = "bobyqa", optCtrl = list(maxfun = 5e+05))
#
#      AIC      BIC   logLik deviance df.resid
#   1596.6   1665.1   -784.3   1568.6      971
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.3270 -0.3431  0.2388  0.4550  1.8180
#
# Random effects:
#  Groups                   Name        Variance Std.Dev.
#  overdispersion           (Intercept) 0.51959  0.7208
#  site.id                  (Intercept) 0.06774  0.2603
#  village:bimonth.assigned (Intercept) 0.30362  0.5510
#  village                  (Intercept) 3.47619  1.8645
#  year.assigned            (Intercept) 0.17855  0.4226
# ...

# %%
# RESIDUAL PLOT
plot(m_5)
# Out:
# plot without title
